# %% [markdown]
# # [Seaborn](https://seaborn.pydata.org/)

# %% [markdown]
# ## Choosing Plot Types and Custom Styles

# %% [markdown]
# **Trends** - A trend is defined as a pattern of change.
# *   *sns.lineplot* - Line charts are best to show trends over a period of time, and multiple lines can be used to show trends in more than one group.
#
# **Relationship** - There are many different chart types that you can use to understand relationships between variables in your data.
#
# *   *sns.barplot* - Bar charts are useful for comparing quantities corresponding to different groups.
#
# *    *sns.heatmap* - Heatmaps can be used to find color-coded patterns in tables of numbers.
#
# *    *sns.scatterplot* - Scatter plots show the relationship between two continuous variables; if color-coded, we can also show the relationship with a third categorical variable.
#
# *      *sns.regplot* - Including a regression line in the scatter plot makes it easier to see any linear relationship between two variables.
#
# *   *sns.lmplot* - This command is useful for drawing multiple regression lines, if the scatter plot contains multiple, color-coded groups.
#
# *   *sns.swarmplot* - Categorical scatter plots show the relationship between a continuous variable and a categorical variable.
#
#
# **Distribution** - We visualize distributions to show the possible values that we can expect to see in a variable, along with how likely they are.
#
# *   *sns.histplot* - Histograms show the distribution of a single numerical variable.
#
# *   *sns.kdeplot* - KDE plots (or 2D KDE plots) show an estimated, smooth distribution of a single numerical variable (or two numerical variables).
#
# *   *sns.jointplot* - This command is useful for simultaneously displaying a 2D KDE plot with the corresponding KDE plots for each individual variable.

# %% [markdown]
# # plots

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style('darkgrid')

# %% [markdown]
# ### Load Titanic dataset

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## catplot

# %%
sns.catplot(x ="sex", hue ="survived",
kind ="count", data = titanic)
# Out:
# C:\Users\mj749\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x ='embarked', hue ='survived',
kind ='count', col ='pclass', data = titanic)
# Out:
# C:\Users\mj749\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# اکثر مسافران از S سوار شده اند. بنابراین، مقادیر گم شده را می توان با S پر کرد.
# اکثر مسافران کلاس 3 از Q سوار شدند.
# S برای مسافران کلاس 1 و 2 در مقایسه با کلاس 3 خوش شانس به نظر می رسد.

# %% [markdown]
# ## barplot

# %%
titanic['fare_range'] = pd.qcut(titanic['fare'], 4)

# Barplot - Shows approximate values based
# on the height of bars.
sns.barplot(x ='fare_range', y ='survived',
data = titanic)
# Out:
# <Axes: xlabel='fare_range', ylabel='survived'>

# %% [markdown]
# کرایه به معنای کرایه ای است که مسافر پرداخت می کند. از آنجایی که مقادیر در این ستون پیوسته هستند، باید آن‌ها را در سطل‌های جداگانه قرار دهید (همانطور که برای ویژگی سن انجام شد) تا یک ایده واضح داشته باشید. می توان نتیجه گرفت که اگر مسافری کرایه بالاتری پرداخت کند، میزان زنده ماندن بیشتر است.

# %% [markdown]
# ## Joint Plot

# %%
sns.jointplot(x='fare',y='age',data=titanic)

# %% [markdown]
# ## Scatter Plots

# %%
insurance_data = pd.read_csv("insurance.csv")
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data)
# Out:
# C:\Users\mj749\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.swarmplot(x=insurance_data['smoker'],
              y=insurance_data['charges'])
# Out:
# C:\Users\mj749\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='smoker', ylabel='charges'>
# C:\Users\mj749\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 60.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Distribution Plot

# %%
sns.displot(titanic["fare"],kde=True) #without the kde
# Out:
# C:\Users\mj749\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(x='pclass',y='age',data=titanic)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %% [markdown]
# ## violinplot

# %%
sns.violinplot(x ="sex", y ="age", hue ="survived",
data = titanic, split = True)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# این نمودار خلاصه ای از محدوده سنی مردان، زنان و کودکانی که نجات یافته اند را نشان می دهد. میزان بقا -   برای کودکان خوب است. بالا برای زنان در محدوده سنی 20-50. با افزایش سن برای مردان کمتر. از آنجایی که ستون سن مهم است، مقادیر از دست رفته باید با استفاده از ستون نام (تعیین سن بر اساس آقا، خانم و غیره) و یا با استفاده از یک رگرسیون پر شوند. پس از این مرحله می توان ستون دیگری به نام دامنه_سن (بر اساس ستون سن) ایجاد کرد و دوباره داده ها را تجزیه و تحلیل کرد.

# %% [markdown]
# ## factorplot

# %%
# Adding a column Family_Size
# titanic['family_Size'] = 0
titanic['family_size'] = titanic['parch']+titanic['sibsp']

# Adding a column Alone
titanic['Alone'] = 0
titanic.loc[titanic.family_Size == 0, 'alone'] = 1

# Factorplot for Family_Size
sns.factorplot(x ='family_Size', y ='survived', data = titanic)

# Factorplot for Alone
sns.factorplot(x ='alone', y ='survived', data = titanic)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 10
#       7 titanic.loc[titanic.family_Size == 0, 'alone'] = 1
#       9 # Factorplot for Family_Size
# ---> 10 sns.factorplot(x ='family_Size', y ='survived', data = titanic)
#      12 # Factorplot for Alone
#      13 sns.factorplot(x ='alone', y ='survived', data = titanic)
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'

# %% [markdown]
# اگر مسافر تنها باشد، میزان بقا کمتر است.
#
# اگر تعداد خانواده بیشتر از 5 باشد، شانس بقا به میزان قابل توجهی کاهش می یابد.

# %% [markdown]
# ## Swarm plot

# %%
plt.figure(figsize=(5,4))
sns.swarmplot(x='pclass',y='age',data=titanic)
# Out:
# C:\Users\mj749\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 11.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='pclass', ylabel='age'>
# C:\Users\mj749\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 24.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Count plot

# %%
sns.countplot(x='sex',data=titanic)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ## Heat maps

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_numeric=titanic.select_dtypes(exclude=["object","category","bool"])
titanic_numeric
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3   NaN      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
# for heat maps, indexing / correaltions needs to be established
sns.heatmap(data=titanic_numeric.corr(),cmap='coolwarm')
plt.title('titanic.corr()')
# Out:
# Text(0.5, 1.0, 'titanic.corr()')

# %%
group = titanic.groupby(['pclass', 'survived'])
pclass_survived = group.size().unstack()

# Heatmap - Color encoded 2D representation of data.
sns.heatmap(pclass_survived, annot = True, fmt ="d")
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %% [markdown]
# ## Facet Grid

# %%
g = sns.FacetGrid(data=titanic, col='sex')
g.map_dataframe(sns.histplot, 'age',kde=True)
# Out:
# C:\Users\mj749\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Distributions

# %%
iris_data = pd.read_csv("iris.csv")
iris_data
# Out:
#       Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0      1                5.1               3.5                1.4
# 1      2                4.9               3.0                1.4
# 2      3                4.7               3.2                1.3
# 3      4                4.6               3.1                1.5
# 4      5                5.0               3.6                1.4
# ..   ...                ...               ...                ...
# 145  146                6.7               3.0                5.2
# 146  147                6.3               2.5                5.0
# 147  148                6.5               3.0                5.2
# 148  149                6.2               3.4                5.4
# 149  150                5.9               3.0                5.1
#
#      Petal Width (cm)         Species
# 0                 0.2     Iris-setosa
# 1                 0.2     Iris-setosa
# 2                 0.2     Iris-setosa
# ...

# %%
sns.histplot(iris_data['Petal Length (cm)'],kde=True)
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Count'>

# %%
sns.kdeplot(data=iris_data['Petal Length (cm)'], shade=True)
# Out:
# C:\Users\mj749\AppData\Local\Temp\ipykernel_3692\435910338.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris_data['Petal Length (cm)'], shade=True)
# <Axes: xlabel='Petal Length (cm)', ylabel='Density'>

# %%
# 2D KDE plot
sns.jointplot(x=iris_data['Petal Length (cm)'], y=iris_data['Sepal Width (cm)'], kind="kde")

# %%
# Histograms for each species
sns.histplot(data=iris_data, x='Petal Length (cm)', hue='Species')

# Add title
plt.title("Histogram of Petal Lengths, by Species")
# Out:
# Text(0.5, 1.0, 'Histogram of Petal Lengths, by Species')

# %%
# KDE plots for each species
sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue='Species', shade=True)

# Add title
plt.title("Distribution of Petal Lengths, by Species")
# Out:
# C:\Users\mj749\AppData\Local\Temp\ipykernel_3692\1557107132.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue='Species', shade=True)
# Text(0.5, 1.0, 'Distribution of Petal Lengths, by Species')
